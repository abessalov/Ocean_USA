# %%
# %run _startup.ipynb
# Out:
# <style>.container { width:80% !important; }</style>

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
client = OpenAI()

# %% [markdown]
# ### 1. Get the list of main FOMC TOPICS

# %%
df = pd.read_pickle('data/df_statements.pkl')

# skip the text after the members 
def text_shorten(x):
    x = x.split('Voting for')
    return x[0]
df['txt2'] = df['txt'].map(text_shorten)

# %%
# estimate the number of tokens
txt = '\n'.join(df['txt'])
print(
    len(txt),
    len(re.findall('[0-9a-z]+',txt)),
    len(re.findall('[0-9a-z]+',txt)) * 1.5,
)

# estimate number of tokens
txt = '\n'.join(df['txt2'])
print(
    len(txt),
    len(re.findall('[0-9a-z]+',txt)),
    len(re.findall('[0-9a-z]+',txt)) * 1.5,
)
# Out:
# 142010 21405 32107.5
# 123132 18828 28242.0

# %%
txt = '\n'.join(df['txt2'][5:])
prompt1 = f"Create a list of key economic indicators from the following text: {txt}"

completion = client.chat.completions.create(
    model = "gpt-4o",
    temperature = 0,
    messages = [
        {"role": "user", "content": prompt1}
    ]
)

# %%
ch = completion.choices[0]
print(ch.message.content)
# Out:
# Based on the provided text, here is a list of key economic indicators:
#
# 1. **Labor Market Conditions**:
#    - Job gains
#    - Unemployment rate
#
# 2. **Economic Activity**:
#    - Overall economic activity
#    - Household spending
#    - Business fixed investment
#    - Exports
#
# 3. **Inflation**:
#    - Overall inflation rate
#    - Inflation for items other than food and energy
#    - Market-based measures of inflation compensation
#    - Survey-based measures of longer-term inflation expectations
#
# 4. **Federal Funds Rate**:
#    - Target range for the federal funds rate
#
# 5. **Monetary Policy Actions**:
#    - Treasury securities and agency mortgage-backed securities purchases
#    - Repurchase agreement operations
#    - Reduction of holdings of Treasury securities and agency debt
#
# 6. **Financial Conditions**:
#    - Credit conditions for households and businesses
#    - Financial and international developments
#
# 7. **Global Developments**:
#    - Impact of global events such as the coronavirus pandemic and geopolitical tensions (e.g., Russia's invasion of Ukraine)
#
# 8. **Public Health**:
#    - Impact of COVID-19 and vaccination progress on economic conditions
#
# These indicators are used by the Federal Open Market Committee (FOMC) to assess the economic outlook and determine appropriate monetary policy actions.

# %% [markdown]
# ### 2. Get relevant indicators from FRED

# %%
txt_ind = '''
1. **Labor Market Conditions**:
   - Job gains
   - Unemployment rate

2. **Economic Activity**:
   - Overall economic activity
   - Household spending
   - Business fixed investment
   - Exports
   - Production

3. **Inflation**:
   - Overall inflation rate
   - Inflation for items other than food and energy
   - Market-based measures of inflation compensation
   - Survey-based measures of longer-term inflation expectations
   - Inflation pressures
   - Inflation expectations

4. **Monetary Policy Actions**:
   - Treasury securities and agency mortgage-backed securities purchases
   - Repurchase agreement operations
   - Reduction of holdings of Treasury securities and agency debt

5. **Financial Conditions**:
   - Credit conditions for households and businesses
   - Financial and international developments

6. **Global Developments**:
   - Impact of global events such as the coronavirus pandemic and geopolitical tensions

'''

# %%
txt_out = 'FRED Index|FRED name|Description|Units|Frequency|Group'
prompt1 = f"""
    You are acting as an economist.
    What indicators can I take from the FRED website to analyze the following economic indicators: {txt_ind},
    Create an output csv file with the following format: {txt_out},
    Separator is |
"""

completion = client.chat.completions.create(
    model = "gpt-4o",
    temperature = 1,
    messages = [
        {"role": "user", "content": prompt1}
    ]
)

# %%
pd.set_option('display.max_colwidth',250)
def create_csv(x):
    x = x.split('```')[1].split('\n')[1:]
    x = [x1.split('|') for x1 in x if x1 != '']
    df_out = pd.DataFrame(x[1:], columns=x[0])
    return df_out

# %%
ch = completion.choices[0]
df_out = create_csv(ch.message.content)
df_out
# Out:
#        FRED Index  \
# 0          PAYEMS
# 1          UNRATE
# 2           GDPC1
# 3             PCE
# 4          PNFICA
# 5           EXPGS
# 6          INDPRO
# 7        CPIAUCSL
# 8        CPILFESL
# 9          T10YIE
# 10           MICH
# 11  H41RESPPALDKN
# 12           REPO
# 13           TOTK
# 14        BOPGSTB
# 15        COVID19
#
#                                                                                    FRED name  \
# 0                                                                     Total Nonfarm Payrolls
# 1                                                                 Civilian Unemployment Rate
# 2                                                                Real Gross Domestic Product
# 3                                                          Personal Consumption Expenditures
# 4                                                    Private Nonresidential Fixed Investment
# 5                                                              Exports of Goods and Services
# 6                                                                Industrial Production Index
# 7                                               Consumer Price Index for All Urban Consumers
# 8                 Consumer Price Index for All Urban Consumers: All Items Less Food & Energy
# 9                                                           10-Year Breakeven Inflation Rate
# 10                                              University of Michigan Inflation Expectation
# 11                          Total Assets: Securities Held Outright: U.S. Treasury Securities
# 12  Overnight Reverse Repurchase Agreements: Treasury Securities Sold by the Federal Reserve
# 13                                                         Total Consumer Credit Outstanding
# 14                                                             Balance on Goods and Services
# 15                                                                     COVID-19 Weekly Cases
#
#                                                                                       Description  \
# 0                             Total nonfarm payroll employment represents job gains in thousands.
# 1     The unemployment rate reflects the number of unemployed as a percentage of the labor force.
# 2                  The real GDP measures the value of economic output adjusted for price changes.
# 3                                              Measures household spending on goods and services.
# 4                                         Private sector investments in structures and equipment.
# 5                                          The value of goods and services exported by a country.
# 6   Measures the output of the industrial sector, including manufacturing, mining, and utilities.
# 7      Reflects overall inflation rate by tracking changes in cost of a basket of consumer goods.
# 8                                           Excludes food and energy for core inflation analysis.
# 9                                                 Market-based measure of inflation compensation.
# 10                                    Survey-based measure of longer-term inflation expectations.
# 11                              Represent monetary policy actions related to Treasury securities.
# 12                                                      Cash management tools to manage reserves.
# 13                                                   Represents credit conditions for households.
# 14                                                 Reflects international financial developments.
# 15                                  Impact of global pandemic on economy and global developments.
#
#                                Units  Frequency                    Group
# 0                          Thousands    Monthly  Labor Market Conditions
# 1                            Percent    Monthly  Labor Market Conditions
# 2   Billions of Chained 2012 Dollars  Quarterly        Economic Activity
# 3                Billions of Dollars    Monthly        Economic Activity
# 4                Billions of Dollars  Quarterly        Economic Activity
# 5                Billions of Dollars  Quarterly        Economic Activity
# 6                     Index 2017=100    Monthly        Economic Activity
# 7                Index 1982-1984=100    Monthly                Inflation
# 8                Index 1982-1984=100    Monthly                Inflation
# 9                            Percent      Daily                Inflation
# 10                           Percent    Monthly                Inflation
# 11               Millions of Dollars     Weekly  Monetary Policy Actions
# 12               Millions of Dollars      Daily  Monetary Policy Actions
# 13               Billions of Dollars    Monthly     Financial Conditions
# 14               Billions of Dollars  Quarterly     Financial Conditions
# 15                             Cases     Weekly      Global Developments

# %%
# Let's repeat several times
txt_out = 'FRED Index|FRED name|Description|Units|Frequency|Group'
prompt1 = f"""
    You are acting as an economist.
    What indicators can I take from the FRED website to analyze the following economic indicators: {txt_ind},
    Create an output csv file with the following format: {txt_out},
    Separator is |
"""

df_out = pd.DataFrame()
for tr in range(5):
    completion = client.chat.completions.create(
        model = "gpt-4o",
        temperature = 1,
        messages = [
            {"role": "user", "content": prompt1}
        ]
    )    
    ch = completion.choices[0]
    df_out1 = create_csv(ch.message.content)
    df_out = pd.concat([df_out, df_out1])
print(df_out.shape)
# Out:
# (87, 7)

# %%
# filter at least 2 times in the list
feats = txt_out.split('|')
df_cnt = df_out.groupby('FRED Index').size()
df_all = df_out.groupby('FRED Index')[feats].last().reset_index(drop = True).sort_values('Group')

print(df_all.shape)
list_ind = list(df_cnt[df_cnt > 1].index)
# df_all = df_all[df_all['FRED Index'].isin(list_ind)]
# print(df_all.shape)
# Out:
# (44, 6)

# %%
# df_all

# %%
# df_all.to_clipboard()

# %% [markdown]
# ### 3. Describe indicators please

# %%
txt_in = '''
GDP
PNFI
PCE
INDPRO
GDPC1
EXPGS
DPCCRV1Q225SBEA
Y033RC1Q027SBEA
CFNAI
DRTSCILM
DTWEXBGS
BUSLOANS
TOTALSL
NFCI
CPILFESL
CPIAUCSL
PCEPI
PCEPILFE
MICH
PAYEMS
UNRATE
EMRATIO
WALCL
EXCSRESNS
TREAST
WSECOUT
GEPUCURRENT
'''

txt_out = 'FRED Index|FRED name|Description|Units|Frequency'
prompt1 = f"""
    You are acting as an economist.
    Take this list of indicators from FRED website: {txt_in},
    Create an output csv file with the following format: {txt_out},
    Separator is |
"""

completion = client.chat.completions.create(
    model = "gpt-4o",
    temperature = 1,
    messages = [
        {"role": "user", "content": prompt1}
    ]
)

ch = completion.choices[0]
df_out = create_csv(ch.message.content)
df_out
# Out:
#          FRED Index  \
# 0               GDP
# 1              PNFI
# 2               PCE
# 3            INDPRO
# 4             GDPC1
# 5             EXPGS
# 6   DPCCRV1Q225SBEA
# 7   Y033RC1Q027SBEA
# 8             CFNAI
# 9          DRTSCILM
# 10         DTWEXBGS
# 11         BUSLOANS
# 12          TOTALSL
# 13             NFCI
# 14         CPILFESL
# 15         CPIAUCSL
# 16            PCEPI
# 17         PCEPILFE
# 18             MICH
# 19           PAYEMS
# 20           UNRATE
# 21          EMRATIO
# 22            WALCL
# 23        EXCSRESNS
# 24           TREAST
# 25          WSECOUT
# 26      GEPUCURRENT
#
#                                                                                FRED name  \
# 0                                                                 Gross Domestic Product
# 1                                                Private Nonresidential Fixed Investment
# 2                                                      Personal Consumption Expenditures
# 3                                                            Industrial Production Index
# 4                                                                               Real GDP
# 5                                                          Exports of Goods and Services
# 6                                                                Durable Goods FRED Code
# 7                                                                  Unspecified FRED Name
# 8                                                    Chicago Fed National Activity Index
# 9                                                          Delinquency Rate on All Loans
# 10                                                        Trade Weighted US Dollar Index
# 11                                                       Commercial and Industrial Loans
# 12                                           Total Consumer Credit Owned and Securitized
# 13                                                   National Financial Conditions Index
# 14            Consumer Price Index for All Urban Consumers: All Items Less Food & Energy
# 15                               Consumer Price Index for All Urban Consumers: All Items
# 16                                         Personal Consumption Expenditures Price Index
# 17  Personal Consumption Expenditures Excluding Food and Energy (Chain-Type Price Index)
# 18                                            University of Michigan: Consumer Sentiment
# 19                                                          All Employees: Total Nonfarm
# 20                                                                     Unemployment Rate
# 21                                                           Employment Population Ratio
# 22             Assets: Total Assets: Total Assets (Less Eliminations from Consolidation)
# 23                                            Excess Reserves of Depository Institutions
# 24                                                                   Treasury Securities
# 25                                                                 Unspecified FRED Name
# 26                                              Global Economic Policy Uncertainty Index
#
#                                                                            Description  \
# 0                                  Total value of goods produced and services provided
# 1                                          Expenditures on private sector fixed assets
# 2                                     Expenditures by households on goods and services
# 3                                       Output of the industrial sector of the economy
# 4                     Inflation-adjusted value of goods produced and services provided
# 5                                                   Total export of goods and services
# 6                                                              Unspecified description
# 7                                                              Unspecified description
# 8   A weighted average of 85 existing monthly indicators of national economic activity
# 9                                 Loan payment defaults as a percentage of total loans
# 10               A comparison of the U.S dollar against a basket of foreign currencies
# 11                  Loans granted to businesses for commercial and industrial purposes
# 12                  Total consumer credit owned, plus credit that has been securitized
# 13                                   A comprehensive gauge of U.S financial conditions
# 14                                                CPI excluding food and energy prices
# 15                                      Broad measure of inflation for the U.S economy
# 16                             Price index measuring personal consumption expenditures
# 17                                                   Price index minus food and energy
# 18                     Measures the confidence of consumers in the economic activities
# 19                                       Number of nonfarm payroll employees in the US
# 20  Percentage of total labor force that is unemployed but actively seeking employment
# 21                           Ratio of the employed to the total working-age population
# 22                                                      Federal Reserve's total assets
# 23       Excess reserves held by depository institutions in the Federal Reserve system
# 24                                               Value of U.S Treasury securities held
# 25                                                             Unspecified description
# 26                                         Index measuring economic policy uncertainty
#
#                                Units              Frequency
# 0                Billions of Dollars              Quarterly
# 1                Billions of Dollars              Quarterly
# 2                Billions of Dollars                Monthly
# 3                     Index 2017=100                Monthly
# 4   Billions of Chained 2012 Dollars              Quarterly
# 5                Billions of Dollars              Quarterly
# 6                  Unspecified units  Unspecified frequency
# 7                  Unspecified units  Unspecified frequency
# 8        Index, 0 = historical trend                Monthly
# 9                         Percentage              Quarterly
# 10                    Index 1973=100                  Daily
# 11               Billions of Dollars                 Weekly
# 12               Billions of Dollars                Monthly
# 13                             Index                 Weekly
# 14               Index 1982-1984=100                Monthly
# 15               Index 1982-1984=100                Monthly
# 16                    Index 2012=100                Monthly
# 17                    Index 2012=100                Monthly
# 18                             Index                Monthly
# 19              Thousands of Persons                Monthly
# 20                        Percentage                Monthly
# 21                        Percentage                Monthly
# 22               Millions of Dollars                 Weekly
# 23               Millions of Dollars                 Weekly
# 24               Billions of Dollars                Monthly
# 25                 Unspecified units  Unspecified frequency
# 26                    Index 2010=100                Monthly

# %%
df_out.to_clipboard()

# %% [markdown]
# ### 4. The final indicators table

# %%
# The final table of indexes
df_all = pd.read_clipboard()
df_all
# Out:
#                       Group      FRED Index  \
# 0         Economic Activity             GDP
# 1         Economic Activity           GDPC1
# 2         Economic Activity           EXPGS
# 3         Economic Activity            PNFI
# 4         Economic Activity          INDPRO
# 5         Economic Activity           CFNAI
# 6      Financial Conditions         TOTBKCR
# 7      Financial Conditions  DPSACBW027SBOG
# 8      Financial Conditions         STLFSI4
# 9      Financial Conditions            NFCI
# 10                Inflation        CPILFESL
# 11                Inflation        CPIAUCSL
# 12                Inflation             PCE
# 13                Inflation           PCEPI
# 14                Inflation        PCEPILFE
# 15                Inflation            MICH
# 16  Labor Market Conditions          PAYEMS
# 17  Labor Market Conditions          UNRATE
# 18  Labor Market Conditions         EMRATIO
# 19  Monetary Policy Actions         WSECOUT
#
#                                                            Name  \
# 0                                        Gross Domestic Product
# 1                                   Real Gross Domestic Product
# 2                                 Exports of Goods and Services
# 3                       Private Nonresidential Fixed Investment
# 4                                   Industrial Production Index
# 5                           Chicago Fed National Activity Index
# 6                             Bank Credit, All Commercial Banks
# 7                                Deposits, All Commercial Banks
# 8                          St. Louis Fed Financial Stress Index
# 9                        Chicago Fed Financial Conditions Index
# 10  CPI for All Urban Consumers: All Items Less Food and Energy
# 11      Consumer Price Index for All Urban Consumers: All Items
# 12                            Personal Consumption Expenditures
# 13                Personal Consumption Expenditures Price Index
# 14                                         Core PCE Price Index
# 15               University of Michigan: Inflation Expectations
# 16                                 All Employees, Total Nonfarm
# 17                                            Unemployment Rate
# 18                                  Employment-Population Ratio
# 19                       Total Assets: Securities Held Outright
#
#                                                                                                          Description  \
# 0                                                  Total market value of all goods and services produced in the U.S.
# 1                                                                                         GDP adjusted for inflation
# 2                                                                         Total value of goods and services exported
# 3                                                                                Business investment in fixed assets
# 4                                                                            Measure of industrial production output
# 5                                                 A weighted average of 85 indicators of national economic activity.
# 6                                                                                  Bank Credit, All Commercial Banks
# 7                                                                                     Deposits, All Commercial Banks
# 8   The STLFSI4 measures the degree of financial stress in the markets and is constructed from 18 weekly data series
# 9          Measures overall financial conditions in money markets, debt and equity markets, and the banking systems.
# 10                                      Consumer Price Index for All Urban Consumers: All Items Less Food and Energy
# 11                                                           Consumer Price Index for All Urban Consumers: All Items
# 12                                                                          Household spending on goods and services
# 13                                      Measures changes in the prices of goods and services consumed by households.
# 14                  PCE index excluding food and energy, used as a preferred inflation gauge by the Federal Reserve.
# 15                        Measures the expected rate of inflation over a one-year horizon based on consumer surveys.
# 16                                                                    Total number of workers in the nonfarm sector.
# 17                                                                  Percentage of the labor force that is unemployed
# 18                                                        Percentage of the working-age population that is employed.
# 19                                                           The amount of securities held by Federal Reserve Banks.
#
#                   Units    Frequency Postprocessing
# 0   Billions of Dollars    Quarterly          pct12
# 1   Billions of Dollars    Quarterly          pct12
# 2   Billions of Dollars    Quarterly          pct12
# 3   Billions of Dollars    Quarterly          pct12
# 4        Index 2017=100  Lag monthly            NaN
# 5                 Index  Lag monthly            NaN
# 6   Billions of Dollars       Weekly          pct12
# 7   Billions of Dollars       Weekly          pct12
# 8                 Index       Weekly            NaN
# 9                 Index       Weekly            NaN
# 10  Index 1982-1984=100      Monthly          pct12
# 11  Index 1982-1984=100      Monthly          pct12
# 12  Billions of Dollars  Lag monthly          pct12
# 13     Index (2012=100)  Lag monthly          pct12
# 14     Index (2012=100)  Lag monthly          pct12
# 15                Index  Lag monthly            NaN
# 16            Thousands      Monthly          pct12
# 17              Percent      Monthly         diff12
# 18              Percent      Monthly         diff12
# 19  Billions of Dollars       Weekly          pct12

# %%
df_all.groupby('Group')['FRED Index'].agg(lambda x: ' '.join(x)).to_dict()
# Out:
# {'Economic Activity': 'GDP GDPC1 EXPGS PNFI INDPRO CFNAI',
#  'Financial Conditions': 'TOTBKCR DPSACBW027SBOG STLFSI4 NFCI',
#  'Inflation': 'CPILFESL CPIAUCSL PCE PCEPI PCEPILFE MICH',
#  'Labor Market Conditions': 'PAYEMS UNRATE EMRATIO',
#  'Monetary Policy Actions': 'WSECOUT'}

# %%
df_all.groupby('Frequency')['FRED Index'].agg(lambda x: ' '.join(x)).to_dict()
# Out:
# {'Lag monthly': 'INDPRO CFNAI PCE PCEPI PCEPILFE MICH',
#  'Monthly': 'CPILFESL CPIAUCSL PAYEMS UNRATE EMRATIO',
#  'Quarterly': 'GDP GDPC1 EXPGS PNFI',
#  'Weekly': 'TOTBKCR DPSACBW027SBOG STLFSI4 NFCI WSECOUT'}

# %%
df_all.groupby('Postprocessing')['FRED Index'].agg(lambda x: ' '.join(x)).to_dict()
# Out:
# {'diff12': 'UNRATE EMRATIO',
#  'pct12': 'GDP GDPC1 EXPGS PNFI TOTBKCR DPSACBW027SBOG CPILFESL CPIAUCSL PCE PCEPI PCEPILFE PAYEMS WSECOUT'}
